# %% [markdown]
# # Download/Unload the Nifty, MidcapNifty, BankNifty, FinNifty Futures Dataset on monthly basis using Breeze API

# %%
from breeze_connect import BreezeConnect
import numpy as np
import pandas as pd
import time

breeze = BreezeConnect(api_key="")
breeze.generate_session(api_secret="", session_token="38879455")

# %% [markdown]
# ## MIDCAP NIFTY - Futures Extraction

# %%
start_date = "2023-12-01T07:00:00.000Z"
end_date = "2023-12-31T18:00:00.000Z"
expiry = "2023-12-22T18:00:00.000Z"

time_interval = "1minute"

futureTempdata = breeze.get_historical_data(interval = time_interval,
                            from_date = start_date,
                            to_date = end_date,
                            stock_code = "NIFSEL",
                            exchange_code = "NFO",
                            product_type = "futures",
                            expiry_date = expiry)

futureTempdata
# Out:
# {'Success': [{'datetime': '2023-12-01 09:15:00',
#    'stock_code': 'NIFSEL',
#    'exchange_code': 'NFO',
#    'product_type': 'Futures',
#    'expiry_date': '22-DEC-23',
#    'right': 'Others',
#    'strike_price': '0',
#    'open': '9725.7',
#    'high': '9729.95',
#    'low': '9715',
#    'close': '9727.6',
#    'volume': '2100',
#    'open_interest': '612150',
#    'count': 0},
#   {'datetime': '2023-12-01 09:16:00',
#    'stock_code': 'NIFSEL',
#    'exchange_code': 'NFO',
#    'product_type': 'Futures',
#    'expiry_date': '22-DEC-23',
#    'right': 'Others',
#    'strike_price': '0',
#    'open': '9729.8',
#    'high': '9760',
#    'low': '9729.8',
#    'close': '9760',
#    'volume': '17250',
#    'open_interest': '612150',
#    'count': 1},
#   {'datetime': '2023-12-01 09:17:00',
#    'stock_code': 'NIFSEL',
#    'exchange_code': 'NFO',
#    'product_type': 'Futures',
#    'expiry_date': '22-DEC-23',
#    'right': 'Others',
#    'strike_price': '0',
#    'open': '9758',
# ...

# %%
future_data = pd.DataFrame(futureTempdata["Success"])
future_data.to_csv("NFO_NIFTYMIDCAP_Future_Dec2023.csv", index=False)

# %%
#Defining a function to be called multiple times

def get_historical_data(stock_code,time_interval, start_date,end_date,expiry,filename):
    futureTempdata = breeze.get_historical_data(interval = time_interval,
                            from_date = start_date,
                            to_date = end_date,
                            stock_code = stock_code,
                            exchange_code = "NFO",
                            product_type = "futures",
                            expiry_date = expiry)
    future_data = pd.DataFrame(futureTempdata["Success"])
    if future_data.shape[0]>0:
        future_data.to_csv(f"{filename}.csv", index=False)

# %%
# Jan Month
start_date = "2024-01-01T07:00:00.000Z"
end_date = "2024-01-31T18:00:00.000Z"
expiry = "2024-01-29T18:00:00.000Z"
stock_code = "NIFSEL"
time_interval = "1minute"

filename = "NFO_NIFTYMIDCAP_Future_Jan2024"
get_historical_data(stock_code,time_interval, start_date,end_date,expiry,filename)

# %%
# Feb Month
start_date = "2024-02-01T07:00:00.000Z"
end_date = "2024-02-29T18:00:00.000Z"
expiry = "2024-02-26T18:00:00.000Z"
stock_code = "NIFSEL"
time_interval = "1minute"

filename = "NFO_NIFTYMIDCAP_Future_Feb2024"
get_historical_data(stock_code,time_interval, start_date,end_date,expiry,filename)

# %%
# March Month
start_date = "2024-03-01T07:00:00.000Z"
end_date = "2024-03-31T18:00:00.000Z"
expiry = "2024-03-22T18:00:00.000Z"

time_interval = "1minute"
stock_code = "NIFSEL"
time_interval = "1minute"

filename = "NFO_NIFTYMIDCAP_Future_Mar2024"
get_historical_data(stock_code,time_interval, start_date,end_date,expiry,filename)

# %% [markdown]
# ## FINNIFTY - Futures Extraction

# %%
def get_historical_data(time_interval, start_date,end_date,expiry,filename):
    futureTempdata = breeze.get_historical_data(interval = time_interval,
                            from_date = start_date,
                            to_date = end_date,
                            stock_code = "NIFFIN",
                            exchange_code = "NFO",
                            product_type = "futures",
                            expiry_date = expiry)
    future_data = pd.DataFrame(futureTempdata["Success"])
    if future_data.shape[0]>0:
        future_data.to_csv(f"{filename}.csv", index=False)

# %%
# finnifty  - expiry date is last tuesday if working day. 
# Dec Month Extraction

start_date = "2023-12-01T07:00:00.000Z"
end_date = "2023-12-31T18:00:00.000Z"
expiry = "2023-12-26T18:00:00.000Z"

time_interval = "1minute"
filename = "NFO_NIFTYFIN_Future_Dec2023"
get_historical_data(stock_code,time_interval, start_date,end_date,expiry,filename)

# %%
# finnifty  - expiry date is last tuesday if working day. 

start_date = "2024-01-01T07:00:00.000Z"
end_date = "2024-01-31T18:00:00.000Z"
expiry = "2024-01-30T18:00:00.000Z"

time_interval = "1minute"
filename = "NFO_NIFTYFIN_Future_Jan2024"
get_historical_data(stock_code,time_interval, start_date,end_date,expiry,filename)

# %%
# finnifty  - expiry date is last tuesday if working day. 

start_date = "2024-02-01T07:00:00.000Z"
end_date = "2024-02-29T18:00:00.000Z"
expiry = "2024-02-27T18:00:00.000Z"

time_interval = "1minute"
filename = "NFO_NIFTYFIN_Future_Feb2024"
get_historical_data(stock_code,time_interval, start_date,end_date,expiry,filename)

# %%
# finnifty  - expiry date is last tuesday if working day. 

start_date = "2024-03-01T07:00:00.000Z"
end_date = "2024-03-31T18:00:00.000Z"
expiry = "2024-03-26T18:00:00.000Z"

time_interval = "1minute"
filename = "NFO_NIFTYFIN_Future_Mar2024"
get_historical_data(stock_code,time_interval, start_date,end_date,expiry,filename)

# %% [markdown]
# ## BANKNIFTY - Future Extraction

# %%
def get_historical_data(stock_code,time_interval, start_date,end_date,expiry,filename):
    futureTempdata = breeze.get_historical_data(interval = time_interval,
                            from_date = start_date,
                            to_date = end_date,
                            stock_code = "CNXBAN",
                            exchange_code = "NFO",
                            product_type = "futures",
                            expiry_date = expiry)
    future_data = pd.DataFrame(futureTempdata["Success"])
    if future_data.shape[0]>0:
        future_data.to_csv(f"{filename}.csv", index=False)
    else:
        print("No data found")

# %%
# Niftybank  - expiry date is last thursday if working day. 

start_date = "2024-03-01T07:00:00.000Z"
end_date = "2024-03-31T18:00:00.000Z"
expiry = "2024-03-27T18:00:00.000Z"

time_interval = "1minute"
filename = "NFO_NIFTYBANK_Future_Mar2024"

get_historical_data(stock_code,time_interval, start_date,end_date,expiry,filename)

# %%
start_date = "2024-02-01T07:00:00.000Z"
end_date = "2024-02-29T18:00:00.000Z"
expiry = "2024-02-29T18:00:00.000Z"

time_interval = "1minute"
filename = "NFO_NIFTYBANK_Future_Feb2024"

get_historical_data(stock_code,time_interval, start_date,end_date,expiry,filename)

# %%
# Niftybank  - expiry date is last thursday if working day. 

start_date = "2024-01-01T07:00:00.000Z"
end_date = "2024-01-31T18:00:00.000Z"
expiry = "2024-01-25T18:00:00.000Z"

time_interval = "1minute"
filename = "NFO_NIFTYBANK_Future_Jan2024"

get_historical_data(stock_code,time_interval, start_date,end_date,expiry,filename)

# %%
# Niftybank  - expiry date is last thursday if working day. 
start_date = "2023-12-01T07:00:00.000Z"
end_date = "2023-12-31T18:00:00.000Z"
expiry = "2023-12-28T18:00:00.000Z"
time_interval = "1minute"
filename = "NFO_NIFTYBANK_Future_Dec2024"

get_historical_data(stock_code,time_interval, start_date,end_date,expiry,filename)

# %% [markdown]
# # NIFTY Futures Extraction

# %%
def get_historical_data(stock_code,time_interval, start_date,end_date,expiry,filename):
    futureTempdata = breeze.get_historical_data(interval = time_interval,
                            from_date = start_date,
                            to_date = end_date,
                            stock_code = "NIFTY",
                            exchange_code = "NFO",
                            product_type = "futures",
                            expiry_date = expiry)
    future_data = pd.DataFrame(futureTempdata["Success"])
    if future_data.shape[0]>0:
        future_data.to_csv(f"{filename}.csv", index=False)
    else:
        print("No data found")

# %%
# Nifty 50  - expiry date is last thursday if working day. 

stock_code = "NIFTY"
start_date = "2024-03-01T07:00:00.000Z"
end_date = "2024-03-31T18:00:00.000Z"
expiry = "2024-03-28T18:00:00.000Z"

time_interval = "1minute"
filename = "NFO_NIFTY_Future_Mar2024"

get_historical_data(stock_code,time_interval, start_date,end_date,expiry,filename)

# %%
# Nifty 50  - expiry date is last thursday if working day. 
start_date = "2024-02-01T07:00:00.000Z"
end_date = "2024-02-29T18:00:00.000Z"
expiry = "2024-02-29T18:00:00.000Z"

time_interval = "1minute"
filename = "NFO_NIFTY_Future_Feb2024"

get_historical_data(stock_code,time_interval, start_date,end_date,expiry,filename)

# %%
# Nifty 50  - expiry date is last thursday if working day. 

start_date = "2024-01-01T07:00:00.000Z"
end_date = "2024-01-31T18:00:00.000Z"
expiry = "2024-01-25T18:00:00.000Z"

time_interval = "1minute"
filename = "NFO_NIFTY_Future_Jan2024"

get_historical_data(stock_code,time_interval, start_date,end_date,expiry,filename)

# %%
# Nifty 50  - expiry date is last thursday if working day. 
start_date = "2023-12-01T07:00:00.000Z"
end_date = "2023-12-31T18:00:00.000Z"
expiry = "2023-12-28T18:00:00.000Z"
time_interval = "1minute"
filename = "NFO_NIFTY_Future_Dec2023"

get_historical_data(stock_code,time_interval, start_date,end_date,expiry,filename)
